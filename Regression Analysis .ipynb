# %% [markdown]
# ## Reading Data

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import zipfile
import warnings
import matplotlib
matplotlib.style.use('ggplot')

# %%
zf=zipfile.ZipFile(r"C:\Users\payal2.bhatia\Downloads\diamonds.csv.zip")

# %%
data1=pd.read_csv(zf.open("diamonds.csv"))
data1.price
# Out:
# 0         326
# 1         326
# 2         327
# 3         334
# 4         335
# 5         336
# 6         336
# 7         337
# 8         337
# 9         338
# 10        339
# 11        340
# 12        342
# 13        344
# 14        345
# 15        345
# 16        348
# 17        351
# 18        351
# 19        351
# 20        351
# 21        352
# 22        353
# 23        353
# 24        353
# 25        354
# 26        355
# 27        357
# 28        357
# 29        357
#          ...
# 53910    2753
# 53911    2753
# 53912    2753
# 53913    2753
# 53914    2753
# 53915    2753
# 53916    2753
# 53917    2753
# 53918    2753
# 53919    2753
# 53920    2755
# 53921    2755
# 53922    2755
# 53923    2756
# 53924    2756
# 53925    2756
# 53926    2756
# 53927    2756
# 53928    2756
# 53929    2756
# 53930    2756
# 53931    2756
# 53932    2757
# 53933    2757
# 53934    2757
# 53935    2757
# 53936    2757
# 53937    2757
# 53938    2757
# 53939    2757
# ...

# %%
sns.distplot(data1.price, color='skyblue', norm_hist=True)
# Out:
# C:\Users\payal2.bhatia\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
import statsmodels.api as sm
sm.qqplot(data1.price)
plt.show()

# %% [markdown]
# ## Checking normality probability plot

# %%
import scipy
from scipy import stats
import seaborn as sns
stats.probplot(data1.price,  plot=sns.mpl.pyplot)
# Out:
# ((array([-4.20855842, -4.00360798, -3.89190134, ...,  3.89190134,
#           4.00360798,  4.20855842]),
#   array([  326,   326,   327, ..., 18806, 18818, 18823], dtype=int64)),
#  (3564.3447364502276, 3932.7997219132358, 0.8933841784930067))

# %%
stats.probplot(data.color,  plot=sns.mpl.pyplot)
# Out:
# ((array([-4.2084746 , -4.00352028, -3.89181139, ...,  3.89181139,
#           4.00352028,  4.2084746 ]), array([0, 0, 0, ..., 6, 6, 6])),
#  (1.6502752554539617, 2.5940281899109787, 0.9699580725382508))

# %%
data=pd.read_csv(zf.open("diamonds.csv"))

# %%
data.head(2)
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
#
#       z
# 0  2.43
# 1  2.31

# %% [markdown]
# ## EDA

# %% [markdown]
# #### Finding missing values

# %%
data.isna().sum()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %% [markdown]
# #### Number of Columns

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z'],
#       dtype='object')

# %% [markdown]
# #### Removing Unnamed Columns

# %%
data.drop("Unnamed: 0" ,inplace=True , axis=1)

# %% [markdown]
# #### Datatypes of Columns

# %%
data.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# price        int64
# x          float64
# y          float64
# z          float64
# dtype: object

# %% [markdown]
# #### Categorical Variables' Counts

# %%
data.cut.value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
data.color.value_counts()
# Out:
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: color, dtype: int64

# %% [markdown]
# #### Finding correlation (Pearson- for numerical variables )

# %%
correlation=data.corr()
correlation
# Out:
#           carat     depth     table     price         x         y         z
# carat  1.000000  0.028224  0.181618  0.921591  0.975094  0.951722  0.953387
# depth  0.028224  1.000000 -0.295779 -0.010647 -0.025289 -0.029341  0.094924
# table  0.181618 -0.295779  1.000000  0.127134  0.195344  0.183760  0.150929
# price  0.921591 -0.010647  0.127134  1.000000  0.884435  0.865421  0.861249
# x      0.975094 -0.025289  0.195344  0.884435  1.000000  0.974701  0.970772
# y      0.951722 -0.029341  0.183760  0.865421  0.974701  1.000000  0.952006
# z      0.953387  0.094924  0.150929  0.861249  0.970772  0.952006  1.000000

# %% [markdown]
# #### Finding correlation with greater than 0.50

# %%
correlation.applymap(lambda x: x if( (x >= 0.50) | (x <= (-0.10)) ) else 0 )
# Out:
#           carat     depth     table     price         x         y         z
# carat  1.000000  0.000000  0.000000  0.921591  0.975094  0.951722  0.953387
# depth  0.000000  1.000000 -0.295779  0.000000  0.000000  0.000000  0.000000
# table  0.000000 -0.295779  1.000000  0.000000  0.000000  0.000000  0.000000
# price  0.921591  0.000000  0.000000  1.000000  0.884435  0.865421  0.861249
# x      0.975094  0.000000  0.000000  0.884435  1.000000  0.974701  0.970772
# y      0.951722  0.000000  0.000000  0.865421  0.974701  1.000000  0.952006
# z      0.953387  0.000000  0.000000  0.861249  0.970772  0.952006  1.000000

# %%
sns.heatmap(correlation)

# %% [markdown]
# #### Renaming columns

# %%
data.rename(columns={"x": "Length", "y":"width", "z": "height"}, inplace=True)

# %%
data.shape
# Out:
# (53940, 10)

# %% [markdown]
# #### Descriptive Statistics

# %%
data.describe()
# Out:
#               carat         depth         table         price        Length  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#               width        height
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
bins= [0.01, 0.05, 0.10, 0.20, 0.30, 0.40, 0.50, 0.60, 0.70, 0.80]
labels=[1,2, 3, 4, 5,6 ,7, 8,9]
data["carat_binned"]=pd.cut(data["carat"],bins=bins, labels=labels)

# %%
sns.kdeplot(data["carat_binned"])
# Out:
# C:\Users\payal2.bhatia\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:448: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# C:\Users\payal2.bhatia\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:448: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# C:\Users\payal2.bhatia\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ###### right skewed

# %%
sns.kdeplot(data["depth"])

# %%
 sns.distplot(data["depth"])

# %% [markdown]
# ###### normally distributed

# %%
sns.kdeplot(data["table"])

# %%
data.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'Length',
#        'width', 'height', 'carat_binned'],
#       dtype='object')

# %%
sns.kdeplot(data["price"])

# %% [markdown]
# ###### right skewed

# %%
sns.kdeplot(data["Length"])

# %%
sns.kdeplot(data["width"])

# %%
sns.kdeplot(data["height"])

# %% [markdown]
# ## Plotting Histogram of all numericl columns

# %%
data[['carat',  'depth', 'table', 'price', 'Length',
       'width', 'height']].hist(bins=16, figsize=(15,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000299437F1860>,
# ...
#       dtype=object)

# %%
sns.countplot(data["cut"])

# %%
sns.countplot(data["clarity"])

# %% [markdown]
# ###### Removing minimum values of Length , width, height

# %%
data.loc[(data["Length"]==0 ) | (data["width"]==0 ) | (data["height"]==0)]
# Out:
#        carat        cut color clarity  depth  table  price  Length  width  \
# 2207    1.00    Premium     G     SI2   59.1   59.0   3142    6.55   6.48
# 2314    1.01    Premium     H      I1   58.1   59.0   3167    6.66   6.60
# 4791    1.10    Premium     G     SI2   63.0   59.0   3696    6.50   6.47
# 5471    1.01    Premium     F     SI2   59.2   58.0   3837    6.50   6.47
# 10167   1.50       Good     G      I1   64.0   61.0   4731    7.15   7.04
# 11182   1.07      Ideal     F     SI2   61.6   56.0   4954    0.00   6.62
# 11963   1.00  Very Good     H     VS2   63.3   53.0   5139    0.00   0.00
# 13601   1.15      Ideal     G     VS2   59.2   56.0   5564    6.88   6.83
# 15951   1.14       Fair     G     VS1   57.5   67.0   6381    0.00   0.00
# 24394   2.18    Premium     H     SI2   59.4   61.0  12631    8.49   8.45
# 24520   1.56      Ideal     G     VS2   62.2   54.0  12800    0.00   0.00
# 26123   2.25    Premium     I     SI1   61.3   58.0  15397    8.52   8.42
# ...

# %% [markdown]
# ###### Restoring all the rows except above or drop above all

# %%
data=data[(data[["Length", "width", "height"]] !=0).all(axis=1)]

# %%
data.loc[(data["Length"]==0 ) | (data["width"]==0 ) | (data["height"]==0)] # check
# Out:
# Empty DataFrame
# Columns: [carat, cut, color, clarity, depth, table, price, Length, width, height, carat_binned]
# Index: []

# %% [markdown]
# #### Scaling of all Features

# %%
sns.catplot(data=data, aspect=2)

# %% [markdown]
# #### Jointplot

# %% [markdown]
# ## Carat vs Price ; Carat_binned vs price

# %%
sns.jointplot(data["carat"], data["price"])

# %%
sns.jointplot(data["carat_binned"], data["price"])

# %% [markdown]
# ## Cut vs Price

# %%
sns.barplot(data["cut"], data["price"])

# %% [markdown]
# ## Color vs Price -- Color of the diamond, with D being the best and J the worst

# %%
sns.factorplot(x=data["color"], y=data["price"],data=data, kind="bar")
# Out:
# C:\Users\payal2.bhatia\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-202-1494b3d08c66> in <module>
# ----> 1 sns.factorplot(x=data["color"], y=data["price"],data=data, kind="bar")
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py in factorplot(*args, **kwargs)
#    3674     kwargs.setdefault("kind", "point")
#    3675
# -> 3676     return catplot(*args, **kwargs)
#    3677
#    3678
#
# ...

# %%
sns.factorplot(x=data["color"], y=data["price"],data=data, kind="violin")

# %%
sns.countplot(data["color"])

# %% [markdown]
# ###### J is worst color and  still has highest price -- but sold very less

# %% [markdown]
# ## Color vs Cut

# %% [markdown]
# ## conditional Plot

# %%
cond_plot=sns.FacetGrid(data=data,col="color" )
cond_plot.map(sns.violinplot, "cut")
# Out:
# C:\Users\payal2.bhatia\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\axisgrid.py:715: UserWarning: Using the violinplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# C:\Users\payal2.bhatia\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# Faceting is multivariate because after laying out one (categorical) variable in the rows
# and another (categorical) variable in the columns, we are already at two variables accounted
# for before regular plotting has even begun

# %%
sns.pairplot(data[["cut", "color", "table"]])

# %% [markdown]
# ###### In color D , one of the best color, popular cut is good ; , color I is important since it sells in "Fair " cut and sold in each price catrgory with an expensive prices

# %% [markdown]
# ## Clarity vs price

# %%
sns.boxplot(data["clarity"], data["price"])

# %% [markdown]
# ###### VS1 and VS2 affect the Diamond's Price equally having quite high Price margin.

# %% [markdown]
# ## Depth vs Price

# %%
sns.jointplot(data["depth"], data["price"])

# %% [markdown]
# ###### On same depth also, price varies

# %% [markdown]
# ## Table vs price

# %%
sns.jointplot(data["table"], data["price"])

# %%
cond_plot2=sns.FacetGrid(data=data,col="table", col_wrap=4, )
cond_plot2.map(sns.scatterplot, "depth", "price")

# %% [markdown]
# ## As the Dimensions increases, Obviously the Prices Rises as more and more Natural Resources are Utilised.

# %%
sns.kdeplot(data["Length"], color="orange")
sns.kdeplot(data["width"], color="blue")
sns.kdeplot(data["height"] , color="red")
plt.xlim(0, 12)

# %% [markdown]
# ## Re-Scaling Price

# %% [markdown]
# #### PRE-PROCESSING

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler, LabelEncoder
data_copy1=data.copy()
std_scaler=StandardScaler()
data_copy1.dropna(inplace= True, axis=0)
data_copy1.drop(data[["color", "clarity", "cut", "carat_binned"]], inplace=True, axis=1)
# data_copy.drop(["carat_binned "], axis=1, inplace=True)

# %%
data_copy1.columns

# %%
std_scale_price=std_scaler.fit_transform(data_copy1)

# %%
data_copy1["price"].head(5)

# %% [markdown]
# ## Feature Engineering

# %%
data["Volume"]=data["Length"]*data["width"]*data["height"]

# %% [markdown]
# ## Volume vs Price

# %%
sns.jointplot(data["Volume"], data["price"],xlim=(0,500))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Volume'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-203-7932e866f072> in <module>
# ...

# %% [markdown]
# ###### with increase in volume , price rapidly increase

# %%
data.drop(data[["Length", "width", "height"]], inplace=True, axis=1)

# %% [markdown]
# ## Label Encoding

# %%
le=LabelEncoder()

# %%
data["cut"]=le.fit_transform(data["cut"])
data["clarity"]=le.fit_transform(data["clarity"])
data["color"]=le.fit_transform(data["color"])

# %%
data.head(2)
# Out:
#    carat  cut  color  clarity  depth  table  price carat_binned
# 0   0.23    2      1        3   61.5   55.0    326            4
# 1   0.21    3      1        2   59.8   61.0    326            4

# %%
data["price"]=data1["price"] # since I made sahllow copy of data and scaled the price in that copy which relected in original as well

# %%
data.head(2)
# Out:
#    carat  cut  color  clarity  depth  table  price carat_binned
# 0   0.23    2      1        3   61.5   55.0    326            4
# 1   0.21    3      1        2   59.8   61.0    326            4

# %% [markdown]
# ## Modelling

# %%
Y=data["price"]
binned_carat = data["carat_binned"]

# %%
data.drop(data[["price", "carat_binned"]], axis=1, inplace=True)

# %%
from sklearn.model_selection import train_test_split, GridSearchCV, KFold, cross_val_score, cross_validate
from sklearn.feature_selection import RFECV 
# Feature ranking with recursive feature elimination and cross-validated selection of the best number of features.
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import AdaBoostRegressor, BaggingRegressor,GradientBoostingRegressor,RandomForestRegressor
from  sklearn.linear_model import Lasso, LinearRegression,ridge_regression,SGDRegressor, Ridge
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error,r2_score

# %%
X_train, X_test, y_train, y_test=train_test_split(data, Y, )

# %%
X_train.shape, X_test.shape, y_test.shape, y_train.shape
# Out:
# ((40440, 6), (13480, 6), (13480,), (40440,))

# %%
models=['Linear Regression' , 'Lasso Regression' , 'AdaBoost Regression' , "Ridge Regression",  'GradientBoosting Regression',
          'RandomForest Regression' ,
         'KNeighbours Regression']
r2_scores=[]

# %%
LR=LinearRegression()
LassR=Lasso()
AdaR=AdaBoostRegressor()
ridge_R=Ridge()
GBR=GradientBoostingRegressor()
RfR=RandomForestRegressor()
KNNR=KNeighborsRegressor()
# models_2=[LR, ]

# %%
model=[LR, LassR, AdaR,ridge_R,GBR,RfR, KNNR]
rmse=[]

# %% [markdown]
# ##### Training Error

# %%
rmse_training=[]
r2_scores_training=[]

# %%
# for i in model:
#     clf=i
# #     clf.fit(X_train, y_train)
#     y_pred=clf.predict(X_train)
#     score=r2_score(y_train, y_pred)
#     r2_scores_training.append(score)
#     mse=mean_squared_error(y_train, y_pred)
#     rmse_training.append(mse)

# %%
d={"Model":models, "R2":r2_scores_training, "MSE": rmse_training }

# %%
len(models),len(rmse_training), len(r2_scores_training)
# Out:
# (7, 0, 0)

# %%
training_model_result=pd.DataFrame(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-06d92fd9be04> in <module>
# ----> 1 training_model_result=pd.DataFrame(d)
#
# NameError: name 'pd' is not defined

# %%
# training_model_result

# %%
for i in model:
    clf=i
    clf.fit(X_train, y_train)
    y_pred=clf.predict(X_test)
    score=r2_score(y_test, y_pred)
    r2_scores.append(score)
    mse=mean_squared_error(y_test, y_pred)
    rmse.append(mse)
# Out:
# C:\Users\payal2.bhatia\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
r2_scores
# Out:
# [0.8784700393674083,
#  0.8784764254948472,
#  0.8926289332144088,
#  0.8784717595238443,
#  0.9705892940722958,
#  0.9779678728822013,
#  0.7917248775993321]

# %%
d={"Model":models, "R2":r2_scores, "MSE": rmse }
len(models),len(rmse), len(r2_scores)
# Out:
# (7, 7, 7)

# %%
model_result=pd.DataFrame(d)

# %%
model_result
# Out:
#                          Model        R2           MSE
# 0            Linear Regression  0.878470  1.917509e+06
# 1             Lasso Regression  0.878476  1.917408e+06
# 2          AdaBoost Regression  0.892629  1.694109e+06
# 3             Ridge Regression  0.878472  1.917482e+06
# 4  GradientBoosting Regression  0.970589  4.640444e+05
# 5      RandomForest Regression  0.977968  3.476246e+05
# 6       KNeighbours Regression  0.791725  3.286181e+06

# %%
model_result.sort_values(by=["R2", "MSE"], ascending=[False, True])
# Out:
#                          Model        R2           MSE
# 5      RandomForest Regression  0.977968  3.476246e+05
# 4  GradientBoosting Regression  0.970589  4.640444e+05
# 2          AdaBoost Regression  0.892629  1.694109e+06
# 1             Lasso Regression  0.878476  1.917408e+06
# 3             Ridge Regression  0.878472  1.917482e+06
# 0            Linear Regression  0.878470  1.917509e+06
# 6       KNeighbours Regression  0.791725  3.286181e+06

# %%
sns.barplot( "R2","Model", data=model_result)

# %%
sns.factorplot( "Model","R2", data=model_result, aspect=5)
# Out:
# C:\Users\payal2.bhatia\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# ## Another Approach

# %% [markdown]
# There are a number of assupmtions we made about the data and these must be met for a linear model to work successfully and the standard residual plots can help validate some of these.

# %%
import statsmodels.api as sm

# %%
X_train.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table'], dtype='object')

# %%
stats_model_withoutInt=sm.OLS(y_train,X_train, data=data).fit() # Note: unlike sklearn isme pehle DV aaega then IVs

# %%
stats_model_withoutInt.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.939
# Model:                            OLS   Adj. R-squared:                  0.939
# Method:                 Least Squares   F-statistic:                 1.035e+05
# Date:                Fri, 05 Jul 2019   Prob (F-statistic):               0.00
# Time:                        17:26:43   Log-Likelihood:            -3.4992e+05
# No. Observations:               40440   AIC:                         6.998e+05
# Df Residuals:                   40434   BIC:                         6.999e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# carat       8331.7738     15.748    529.066      0.000    8300.907    8362.640
# ...

# %% [markdown]
# The first table i.e. overall model statistics, you can learn about:
#
# R-Squared, which is an estimate of the strength of the relationship between your model and the response variable that lies between 0 (worst) and 1 (best), is 0.278 for your model. While from experience this is quite low, but one can not jump into a conclusion by simply only looking at only R-Squared! I think you can still do better.
#
# F-Stat: It is a statistical test that compare the fit of the intercept-only model with your model. In simple works, if P value for the F-Stat (here Prob (F-Statistic) is less than your significance level, one can reject the null hypothesis that a intercept-only model is better, meaning your model is better a better job (Not a big surprise honestly).
#
# The second table i.e. summary of statistics of your model breakdown:
#
# Gives a lot of information about each variable. Each coefficient with its corresponding standard error, t-statistic, p-value. For instance, for each coefficient if the t-statistic is large (or simply the p-value is ZERO or very very small < 0.05), that particular coefficient is trustworthy like discount or stockout, otherwise the error is large and unlikely any interpretation from them to be reliable like some of the sublevels of prod_function or prod_regime categorical variables in your model. *Just a rough thought about these variables in your model, maybe the type of categorical encoding you do on these is not performing well, that is why the errors here are large?!
#
# How To Interpret Your Model:
#
# This is an interesting part. Taking that your model is good enough (within the defined confidence interval), one can find out how each of these variables contribute to the dependant variable (herein sales).
#
# Specifically for the discount variable, if all other variables are fixed, then for each change of 1 unit in discount, sales changes, on average, by 0.4146 units (the coefficient of the discount from your model).

# %% [markdown]
#             coef	std err	 t	     P>|t|	[0.025	0.975]
#
# carat	8363.9322	15.730	531.721	0.000	8333.101	8394.763
#
# CI Level: [8333.101,	8394.763]

# %%
d2=dict(x=[2,0,0,0,56,56])
d2
# Out:
# {'x': [2, 0, 0, 0, 56, 56]}

# %%
stats_model_withoutInt.params
# Out:
# carat      8331.773846
# cut          86.807376
# color      -257.571128
# clarity     312.393020
# depth       -10.629571
# table       -48.911633
# dtype: float64

# %%
stats_model_withoutInt.predict([2,0,0,0,56,56])
# Out:
# array([13329.24028446])

# %%
stats_model_withoutInt.get_prediction([2,0,0,0,56,56])
stats_model_withoutInt.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                   Results: Ordinary least squares
# ...
# Model:              OLS              Adj. R-squared:     0.939
# Dependent Variable: price            AIC:                699845.6809
# Date:               2019-07-05 17:32 BIC:                699897.3264
# No. Observations:   40440            Log-Likelihood:     -3.4992e+05
# Df Model:           6                F-statistic:        1.035e+05
# Df Residuals:       40434            Prob (F-statistic): 0.00
# R-squared:          0.939            Scale:              1.9198e+06
# ---------------------------------------------------------------------
#             Coef.    Std.Err.     t      P>|t|     [0.025     0.975]
# ---------------------------------------------------------------------
# carat     8331.7738   15.7481  529.0664  0.0000  8300.9073  8362.6404
# cut         86.8074    6.8163   12.7353  0.0000    73.4473   100.1674
# ...

# %%
sns.regplot(data , y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-325-8e3cd3dc7e05> in <module>
# ----> 1 sns.regplot(data , y_pred)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     779                                  order, logistic, lowess, robust, logx,
#     780                                  x_partial, y_partial, truncate, dropna,
# --> 781                                  x_jitter, y_jitter, color, label)
#     782
#     783     if ax is None:
#
# ...

# %% [markdown]
# https://dss.princeton.edu/online_help/analysis/interpreting_regression.htm

# %% [markdown]
# # ANOTHER :

# %%
missing_values = []
nonumeric_values = []

# %%
for i in data:
    uniq=data[i].unique()
    print(i,uniq.size)
    if (uniq.size>10) :
        print(type(uniq))
        print(uniq[0:10])
        print("\n---------------------------------------------")
        
# Find features with missing values
    if (True in pd.isnull(uniq)):
        s = "{} has {} missing" .format(column, pd.isnull(train[i]).sum())
        missing_values.append(s)
# Out:
# carat 273
# <class 'numpy.ndarray'>
# [0.23 0.21 0.29 0.31 0.24 0.26 0.22 0.3  0.2  0.32]
#
# ---------------------------------------------
# cut 5
# color 7
# clarity 8
# depth 184
# <class 'numpy.ndarray'>
# [61.5 59.8 56.9 62.4 63.3 62.8 62.3 61.9 65.1 59.4]
#
# ---------------------------------------------
# table 127
# <class 'numpy.ndarray'>
# [55. 61. 65. 58. 57. 56. 54. 62. 59. 63.]
#
# ---------------------------------------------

# %% [markdown]
# #### Check skewness -- close to zero is less skewed

# %%
data.skew()
# Out:
# carat      1.116207
# cut       -0.187253
# color      0.189630
# clarity    0.175104
# depth     -0.081726
# table      0.796799
# dtype: float64

# %% [markdown]
# #### Kurtosis is a measure of the "tailedness" of the probability distribution of a real-valued random variable.

# %%
data.kurt()
# Out:
# carat      1.255240
# cut       -0.466114
# color     -0.866965
# clarity   -0.821451
# depth      5.746307
# table      2.801738
# dtype: float64

# %%
sns.distplot(data["carat"])
# Out:
# C:\Users\payal2.bhatia\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
data.boxplot(column="carat")

# %% [markdown]
# ### Logaritrhmic Transformation of Y - DV

# %%
prices=pd.DataFrame({"price": Y, "log(price+1)" : np.log1p(Y)})

# %%
plt.rcParams['figure.figsize'] = (6.0, 3.0)
prices.hist(bins=5,)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000029952DF1828>,
# ...
#       dtype=object)

# %%
sns.kdeplot(prices.price)
# Out:
# C:\Users\payal2.bhatia\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### Logarithmic Tranformation of Carat

# %%
carat=pd.DataFrame({"carat": data["carat"], "log(carat+1)" : np.log1p(data["carat"])})
plt.rcParams['figure.figsize'] = (6.0, 3.0)
carat.hist(bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002995494B358>,
# ...
#       dtype=object)

# %%
sns.distplot(carat.carat )
# Out:
# C:\Users\payal2.bhatia\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(carat["log(carat+1)"])
# Out:
# C:\Users\payal2.bhatia\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
import IPython
from IPython.display import Image
Image(filename='Seaborn.PNG')

# %%
Image(filename='seaborn2.PNG')

# %%
Image(filename='seaborn3.PNG')

# %% [markdown]
# https://www.kaggle.com/residentmario/plotting-with-seaborn
# https://www.kaggle.com/residentmario/faceting-with-seaborn#Examples
# https://www.kaggle.com/residentmario/multivariate-plotting

# %% [markdown]
# ### KDE plots can also be used in two dimensions.

# %%
sns.kdeplot(data.loc[:, ["table", "cut"]].sample(2000))
# Out:
# C:\Users\payal2.bhatia\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\distributions.py:679: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)

# %%
sns.jointplot(x=data["carat"], y=Y, kind="hex"), sns.jointplot(x=data["carat"], y=Y, kind="scatter")
# Out:
# (<seaborn.axisgrid.JointGrid at 0x299557a5f60>,
#  <seaborn.axisgrid.JointGrid at 0x299558a4ba8>)

# %%
sns.scatterplot(carat.carat, prices.price)

# %%
sns.scatterplot(carat["log(carat+1)"], prices["log(price+1)"])

# %% [markdown]
# ## It is a non-linear relationship and dispersion(variance) of the relationship also increases as carat size increases.`

# %%
CaraPricData=pd.DataFrame({"carat": carat.carat, "price":prices.price})

# %%
CaraPricData.corr().abs()
# Out:
#           carat     price
# carat  1.000000  0.921592
# price  0.921592  1.000000

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf 
print ("OLS regression model for the association between price and carat")
# reg1 is the model name , followed by equal sign. 
reg1 = smf.ols(formula = 'price ~ carat', data=CaraPricData).fit()
# print the result
print (reg1.summary())
# Out:
# OLS regression model for the association between price and carat
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.849
# Model:                            OLS   Adj. R-squared:                  0.849
# Method:                 Least Squares   F-statistic:                 3.039e+05
# Date:                Mon, 08 Jul 2019   Prob (F-statistic):               0.00
# Time:                        16:29:55   Log-Likelihood:            -4.7253e+05
# No. Observations:               53920   AIC:                         9.451e+05
# Df Residuals:                   53918   BIC:                         9.451e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# Equation: price = -2255.768 + 7755.7673 * carat

# %%
from scipy import stats

# %%
stats.probplot(reg1.resid, plot=sns.mpl.pyplot)
# Out:
# ((array([-4.2084746 , -4.00352028, -3.89181139, ...,  3.89181139,
#           4.00352028,  4.2084746 ]),
#   array([-18582.62515579, -14499.53297513, -14384.78169027, ...,
#           12071.0978252 ,  12236.0978252 ,  12731.77084282])),
#  (1447.7702523509208, 3.40322994215395e-12, 0.9353684355298589))

# %% [markdown]
# ## OR --#Q-Q plot for normality

# %%
sm.qqplot(reg1.resid, line="r")

# %% [markdown]
# ### RESIDUAL PLOT

# %%
sns.residplot("carat", "price", data=CaraPricData)

# %% [markdown]
#  funnel shape-- You can see a similar pattern. To overcome this situation, we’ll build another model with log(y).

# %% [markdown]
# ### NEW MODEL WITH TRANSFORMATION

# %%
CaraPricData["logprice"]=prices["log(price+1)"]
CaraPricData["logcarat"]=carat["log(carat+1)"]

# %%
reglog=smf.ols(formula="logprice~carat", data=CaraPricData).fit()

# %%
print(reglog.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               logprice   R-squared:                       0.847
# Model:                            OLS   Adj. R-squared:                  0.847
# Method:                 Least Squares   F-statistic:                 2.984e+05
# Date:                Mon, 08 Jul 2019   Prob (F-statistic):               0.00
# Time:                        16:49:17   Log-Likelihood:                -26654.
# No. Observations:               53920   AIC:                         5.331e+04
# Df Residuals:                   53918   BIC:                         5.333e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      6.2159      0.003   1858.064      0.000       6.209       6.222
# ...

# %%
sm.qqplot(reglog.resid, line="r")

# %%
sns.lmplot(x="carat", y="logprice", data=CaraPricData, fit_reg=True)
# Out:
# C:\Users\payal2.bhatia\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.residplot(x="carat", y="logprice", data=CaraPricData,lowess=True )

# %% [markdown]
# it is residual plot not fitted v/s residual plot

# %%
from statsmodels.graphics.gofplots import ProbPlot

# %%
sns.residplot(reglog.fittedvalues, y=CaraPricData["logprice"], lowess=True)

# %% [markdown]
# fitted vs residual `values

# %% [markdown]
# ### ANOVA for linear regression

# %%
from statsmodels.stats.anova import anova_lm
model=smf.ols("logprice~carat", data=CaraPricData)
anova_lm(model.fit())
# Out:
#                df        sum_sq       mean_sq              F  PR(>F)
# carat         1.0  46954.740033  46954.740033  298381.199221     0.0
# Residual  53918.0   8484.802929      0.157365            NaN     NaN

# %%
t-test vs ANOVAThere is a thin line of demarcation amidst t-test
and ANOVA, i.e. when the population means of only two groups is 
to be compared, the t-test is used, but when means of more than 
two groups are to be compared, ANOVA is preferred.
